# %% [markdown]
# # Matplotlib

# %% [raw]
# 1.Matplotlib is a python library used to create 2D graphs and plots by using python scripts.
# 2.It has a module named pyplot which makes things easy for plotting by providing feature to control line styles, font properties, formatting axes etc.
# 3.It supports a very wide variety of graphs and plots namely - histogram, bar charts, power spectra, error charts etc.

# %% [markdown]
# ## Importing Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## setting style

# %%
plt.style.use('classic')

# %% [markdown]
# ## How to display plot

# %%
x=np.linspace(0,10,100)

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.show()

# %% [markdown]
# ## Save figure

# %%
plt.savefig('my_figure.png')

# %%
plt.plot([0, 1, 2, 3, 4], [0, 3, 5, 9, 11])
plt.xlabel('Months')
plt.ylabel('Books Read')
plt.show()
plt.savefig('books_read.png')
